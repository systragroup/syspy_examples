# %%
qpath = r'../../quetzal/' # path to quetzal here
import sys
sys.path.insert(0, qpath)

data = r'inputs/'

# import class
from quetzal.io.gtfs_reader.feed_gtfsk import Feed

# %% [markdown]
# ### Read GTFS

# %%
feed = Feed(path=data + r'accra_trotro', dist_units='m')
feed.describe()
# Out:
#           indicator                          value
# 0          agencies  [AMA Department of Transport]
# 1  running_services                            [0]
# 2          timezone                   Africa/Accra
# 3        start_date                       20190304
# 4          end_date                       20200131
# 5        num_routes                            277
# 6         num_trips                            554
# 7         num_stops                           4171
# 8        num_shapes                            554
# 9   num_frequencies                            554

# %% [markdown]
# ### Map GTFS

# %%
feed.map_stops(
    feed.stops['stop_id']  # IDs of the stops to plot
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c7d108811d0666451ef851be11f157dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c7d108811d0666451ef851be11f157dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c7d108811d0666451ef851be11f157dd = L.map(
#                 &quot;map_c7d108811d0666451ef851be11f157dd&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f06b183bef75003ca1a44d30ccecb269 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c7d108811d0666451ef851be11f157dd);
#
#
#             var fast_marker_cluster_41a3ebce500b292ae8b2842cbc71f705 = (function(){
#                 var callback =     function (row) {
#         var imarker;
#         marker = L.circleMarker(new L.LatLng(row[0], row[1]),
#             {&#x27;radius&#x27;: 8, &#x27;fill&#x27;: &#x27;true&#x27;, &#x27;color&#x27;: &#x27;#fc8d62&#x27;, &#x27;weight&#x27;: 1, &#x27;fillOpacity&#x27;: 0.75}
#         );
#         marker.bindPopup(
#             &#x27;&lt;b&gt;Stop name&lt;/b&gt;: &#x27; + row[2] + &#x27;&lt;br&gt;&#x27; +
#             &#x27;&lt;b&gt;Stop ID&lt;/b&gt;: &#x27; + row[3]
#         );
#         return marker;
#     };
#     ;
#
#                 var data = [[5.5876178, -0.1385354, &quot;Tse Addo&quot;, &quot;5010786347&quot;], [5.6064145, -0.1887972, &quot;Bostal&quot;, &quot;5030747563&quot;], [5.5856485, -0.1416218, &quot;Second Juction&quot;, &quot;5010786348&quot;], [5.5843281, -0.1426688, &quot;Junction&quot;, &quot;5010786349&quot;], [5.601748, -0.2407929, &quot;Fadama&quot;, &quot;SA4990070170&quot;], [5.6135692, -0.1962331, &quot;White Wall&quot;, &quot;SA5092998363&quot;], [5.590827, -0.2326527, &quot;Drug Store&quot;, &quot;SA5064268099&quot;], [5.5783627, -0.2114448, &quot;Kokomlemle (Pro Credit)&quot;, &quot;SA5092998364&quot;], [5.5863151, -0.2095848, &quot;Mallam Attah Market&quot;, &quot;SA5039895714&quot;], [5.6382209, -0.2690014, &quot;Yellow House&quot;, &quot;SA5040917093&quot;], [5.5998619, -0.2376645, &quot;Free Pipe&quot;, &quot;4990070168&quot;], [5.5840866, -0.2082377, &quot;Lapaz Station&quot;, &quot;SA5036738889&quot;], [5.5691119, -0.234168, &quot;Welfare&quot;, &quot;SA5064268097&quot;], [5.587401, -0.1675613, &quot;Home touch&quot;, &quot;30730108&quot;], [5.5964991, -0.1994135, &quot;Top Class&quot;, &quot;5039970963&quot;], [5.6388414, -0.2970056, &quot;Omanjor Main station&quot;, &quot;5041783471&quot;], [5.6367199, -0.2935256, &quot;School Junction&quot;, &quot;5041783470&quot;], [5.5258184, -0.25466, &quot;Curve Shiabu&quot;, &quot;5102890841&quot;], [5.5253602, -0.2567437, &quot;Shiabu&quot;, &quot;5102890840&quot;], [5.6477198, -0.298025, &quot;Omanjor&quot;, &quot;5041783474&quot;], [5.5816196, -0.2236549, &quot;Casajan&quot;, &quot;SA5039839197&quot;], [5.5899273, -0.231307, &quot;Immesco Rice&quot;, &quot;SA5039839196&quot;], [5.5762839, -0.223065, &quot;Latex Foam&quot;, &quot;SA5039839199&quot;], [5.5780506, -0.2232712, &quot;SSB&quot;, &quot;SA5039839198&quot;], [5.5890703, -0.2073193, &quot;Master Chef&quot;, &quot;5039970961&quot;], [5.6341761, -0.250826, &quot;Roman&quot;, &quot;5010252541&quot;], [5.567761, -0.2151494, &quot;PTC&quot;, &quot;5040173329&quot;], [5.5556049, -0.257078, &quot;Mataheko&quot;, &quot;5111784811&quot;], [5.6878209, -0.0301026, &quot;Ashaiman Market&quot;, &quot;SA5113398166&quot;], [5.5585986, -0.1611295, &quot;Sergeant Adjettey&quot;, &quot;SA5024136432&quot;], [5.534641, -0.2334234, &quot;Electricity&quot;, &quot;5026822852&quot;], [5.6360717, -0.2981107, &quot;Fan-Milk&quot;, &quot;5051365823&quot;], [5.6330175, -0.2981503, &quot;White House&quot;, &quot;5051365822&quot;], [5.6413781, -0.2052399, &quot;GIMPA&quot;, &quot;SA4981090368&quot;], [5.5562514, -0.1677564, &quot;Vet&quot;, &quot;SA5024136430&quot;], [5.6301744, -0.2194433, &quot;Golf Park&quot;, &quot;SA4981090369&quot;], [5.5693854, -0.1918167, &quot;Immigration&quot;, &quot;SA5113398164&quot;], [5.5516431, -0.1989184, &quot;Ministries&quot;, &quot;SA5113398162&quot;], [5.5576005, -0.205726, &quot;Tigo Office&quot;, &quot;5031322654&quot;], [5.597953, -0.2335625, &quot;Abeka Total&quot;, &quot;5014716659&quot;], [5.5907051, -0.2299199, &quot;Mesco&quot;, &quot;501

# %% [markdown]
# The geometry of a route is the results of the shapely.linemerge operation of all its trips geometries.

# %%
feed.map_routes(
    feed.routes['route_id'].head(10)  # IDs of the routes to plot
)
# Out:
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:1785: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   result[:] = values
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:1785: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   result[:] = values
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:1785: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   result[:] = values
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66b3ddbebc921627f26d701d14a50a70 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66b3ddbebc921627f26d701d14a50a70&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_66b3ddbebc921627f26d701d14a50a70 = L.map(
#                 &quot;map_66b3ddbebc921627f26d701d14a50a70&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_02ea4e5b6d6011c2eba3659fc0ccb1b8 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_66b3ddbebc921627f26d701d14a50a70);
#
#
#             var feature_group_a267dcafb2272d44ed645db304825432 = L.featureGroup(
#                 {}
#             ).addTo(map_66b3ddbebc921627f26d701d14a50a70);
#
#
#         function geo_json_f085c85861d9a009101efae552fee963_styler(feature) {
#             switch(feature.properties.route_id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#66c2a5&quot;};
#             }
#         }
#
#         function geo_json_f085c85861d9a009101efae552fee963_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f085c85861d9a009101efae552fee963 = L.geoJson(null, {
#                 onEachFeature: geo_json_f085c85861d9a009101efae552fee963_onEachFeature,
#
#                 style: geo_json_f085c85861d9a009101efae552fee963_styler,
#         });
#
#         function geo_json_f085c85861d9a009101efae552fee963_add (data) {
#             geo_json_f085c85861d9a009101efae552fee963
#                 .addData(data)
#                 .addTo(feature_group_a267dcafb2272d44ed645db304825432);
#         }
#             geo_json_f085c85861d9a009101efae552fee963_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[-0.2504608, 5.5262255], [-0.2471137, 5.5264894], [-0.2463354, 5.5265416], [-0.2461165, 5.5265513], [-0.2458956, 5.5265638], [-0.2454524, 5.5266151], [-0.2438658, 5.5267631], [-0.2421954, 5.5268947], [-0.241366, 5.5269522], [-0.2405416, 5.5269978], [-0.2398346, 5.5270777], [-0.2394522, 5.5271068], [-0.2390675, 5.5271361], [-0.2384774, 5.5271738], [-0.2378397, 5.5272304], [-0.2370732, 5.5273834], [-0.2363223, 5.5275417], [-0.2361747, 5.5275756], [-0.2357084, 5.5276708], [-0.2348952, 5.5278253], [-0.2339802, 5.5280085], [-0.2334562, 5.5281136], [-0.2328702, 5.5282257], [-0.2317142, 5.5284719], [-0.2310757, 5.5286007], [-0.2304125, 5.5287532], [-0.2297171, 5.5288806], [-0.229099, 5.5290426], [-0.2284418, 5.5291759], [-0.2278117, 5.5293112], [-0.2273274, 5.5294057], [-0.2268352, 5.5295071], [-0.2258774, 5.5296963], [-0.2252197, 5.5298223], [-0.2239658, 5.530051], [-0.2239045, 5.5300478], [-0.2236791, 5.5301012], [-0.2229781, 5.5302511], [-0.2223178, 5.5304028], [-0.2221862, 5.5304267], [-0.2220898, 5.5304517], [-0.2218927, 5.5304943], [-0.2217107, 5.5305422], [-0.2214586, 5.5306129], [-0.2208565, 5.5307972], [-0.2205694, 5.5308799], [-0.2203133, 5.5309607], [-0.2200357, 5.5310561], [-0.2197983, 5.5311382], [-0.2195878, 5.5312083], [-0.218773, 5.5314259], [-0.2182084, 5.5315727], [-0.21768, 5.5317222], [-0.2171932, 5.5318437], [-0.2167238, 5.5319878], [-0.2165897, 5.5320332], [-0.2163939, 5.532104], [-0.2161695, 5.5321794], [-0.216099, 5.5321653], [-0.2160249, 5.5321879], [-0.2158899, 5.5322275], [-0.2157254, 5.5322822], [-0.2154706, 5.532399], [-0.2151648, 5.5325678], [-0.2149764, 5.5326873], [-0.2146601, 5.5328238], [-0.214627, 5.5328375], [-0.2145425, 5.5328635], [-0.2141251, 5.5330214], [-0.2139538, 5.5330851], [-0.2138143, 5.5331105], [-0.2136359, 5.5331225], [-0.2133831, 5.5331185], [-0.2131578, 5.5331065], [-0.212907, 5.5330878], [-0.2127153, 5.5330838], [-0.2126, 5.5330831], [-0.2124564, 5.5331071], [-0.2123297, 5.5331552], [-0.2122291, 5.5332119], [-0.2120984, 5.5332973], [-0.2120243, 5.5333621], [-0.2118462, 5.5335176], [-0.2117011, 5.5336447], [-0.2115753, 5.5337892], [-0.2114781, 5.5339261], [-0.2114104, 5.5340475], [-0.2112038, 5.5345254], [-0.211063, 5.5348965], [-0.2109142, 5.5352542], [-0.210831, 5.5354985], [-0.2107841, 5.5356987], [-0.2107506, 5.535919], [-0.2107425, 5.5361085], [-0.2107224, 5.5363368], [-0.2107022, 5.5364423], [-0.2106648, 5.5365644], [-0.2105943, 5.5366979], [-0.2104877, 5.5368454], [-0.2103643, 5.5369662], [-0.2100673, 5.5372324], [-0.2100036, 5.5372872], [-0.2095905, 5.537663], [-0.2093605, 5.5378919], [-0.2090339, 5.5382303], [-0.2087604, 5.5385473], [-0.2083775, 5.5389531], [-0.2078746, 5.5395378], [-0.2073669, 5.5402506], [-0.2069405, 5.5408312], [-0.2065475, 5.5413425], [-0.2064946, 5.5414206], [-0.206258, 5.5417222], [-0.205879, 5.5422108], [-0.2057382, 5.5424043], [-0.2056014, 5.5425625], [-0.2053647, 5.5428488

# %%
feed.map_trips(
    feed.trips.groupby('route_id').first().trip_id  # IDs of the trips to plot: one per route
)
# Out:
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# ...
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0ac0bdd629eeed6a79ecfce05abc285 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0ac0bdd629eeed6a79ecfce05abc285&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d0ac0bdd629eeed6a79ecfce05abc285 = L.map(
#                 &quot;map_d0ac0bdd629eeed6a79ecfce05abc285&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cfd4868dc6b528d1d395407f248b9afe = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d0ac0bdd629eeed6a79ecfce05abc285);
#
#
#             var feature_group_481efa7988bb233a02a3febe79bf368c = L.featureGroup(
#                 {}
#             ).addTo(map_d0ac0bdd629eeed6a79ecfce05abc285);
#
#
#             var poly_line_ca27cdb6a92ba0459be63221a0a6d7ee = L.polyline(
#                 [[5.588798, -0.1797093], [5.5887387, -0.1797992], [5.5885978, -0.1798468], [5.5886539, -0.1801828], [5.5887233, -0.1804369], [5.5887852, -0.1806084], [5.5888804, -0.1808306], [5.5889675, -0.1809807], [5.5890459, -0.1810974], [5.5891809, -0.1812802], [5.5894013, -0.1815923], [5.5895671, -0.1818351], [5.5897533, -0.1820948], [5.5898231, -0.1821904], [5.5899151, -0.1823041], [5.590238, -0.1826], [5.5903096, -0.1826571], [5.5903837, -0.1827054], [5.5905183, -0.1827878], [5.5909496, -0.1830058], [5.5916305, -0.1833494], [5.5917172, -0.1833931], [5.5918959, -0.1834832], [5.592025, -0.1835637], [5.592255, -0.1837072], [5.5925846, -0.1839539], [5.5928142, -0.184186], [5.592929, -0.1843181], [5.5930504, -0.184487], [5.5931552, -0.1846547], [5.59326, -0.1848612], [5.5934288, -0.185228], [5.5935645, -0.1855321], [5.5939614, -0.1864759], [5.5945004, -0.1876799], [5.5946601, -0.1879894], [5.5947659, -0.1881745], [5.5948655, -0.188348], [5.5952441, -0.1888717], [5.5954096, -0.1891305], [5.5954683, -0.1892028], [5.5955089, -0.1892601], [5.5955257, -0.189282], [5.5957486, -0.1896025], [5.5958487, -0.1897448], [5.5960223, -0.1899883], [5.5980816, -0.1930399], [5.5985534, -0.1937312], [5.5989491, -0.1943025], [5.5990626, -0.1944735], [5.5991639, -0.194613], [5.5994571, -0.1950502], [5.5997693, -0.1955357], [5.5999482, -0.1958133], [5.6002511, -0.1962089], [5.6004353, -0.196449], [5.6005361, -0.1966112], [5.6005597, -0.1966318], [5.6005781, -0.196657], [5.6005906, -0.1966858], [5.6008077, -0.1971074], [5.6009493, -0.1973368], [5.601076, -0.1975326], [5.6013282, -0.1978759], [5.6015886, -0.198285], [5.6018729, -0.1987356], [5.6024668, -0.1996488], [5.6035095, -0.2012452], [5.6045408, -0.2028392], [5.6050017, -0.2035278], [5.605159, -0.2037706], [5.6054836, -0.2042729], [5.6055425, -0.2043603], [5.6066815, -0.2061168], [5.6068011, -0.2062966], [5.6071799, -0.2068739], [5.6074232, -0.207246], [5.6075593, -0.2074625], [5.6075901, -0.2075078], [5.6076781, -0.2076295], [5.6083779, -0.2086802], [5.6087869, -0.2092664], [5.6091699, -0.209835], [5.6094408, -0.2102475], [5.6097629, -0.210711], [5.6099426, -0.2109724], [5.609981, -0.2110289], [5.6100479, -0.211108], [5.6101212, -0.2111811], [5.6102421, -0.2113245], [5.6103014, -0.2113916], [5.6103727, -0.2114493], [5.6105289, -0.2115647], [5.6111933, -0.2120077], [5.6116882, -0.2122935], [5.6120204, -0.2124868], [5.6123613, -0.2126412], [5.6126678, -0.2127723], [5.6129525, -0.212909], [5.6134376, -0.2132025], [5.6138011, -0.2134324], [5.6140005, -0.2135427], [5.6141596, -0.2136101], [5.6143115, -0.2136581], [5.6144635, -0.2136908], [5.6145517, -0.2137037], [5.6146312, -0.2136971], [5.6147176, -0.2136669], [5.6148479, -0.213588], [5.6148999, -0.2135232], [5.6150144, -0.2134391], [5.6151067, -0.2134051], [5.6152044, -0.2133931], [5.6153022, -0.2134037], [5.6153951, -0.2134363], [5.6154782, -0.2134893], [5.6155601, -0.2135775], [5.6155926, -0.2136323], [5.6156167, -0.2136914], [5.6156375, -0.2138061], [5.615627, -0.2139222], [5.615586, -0.2140313], [5.6155126, -0.2141305], [5.6154217, -0.2142389], [5.6153757, -0.2143125], [5.6150773, -0.2168446], [5.6148638, -0.2185346], [5.6145019, -0.2202437], [5.614222, -0.2218115], [5.6139962, -0.2226944], [5.6139687, -0.222793], [5.6138522, -0.2232107], [5.6137322, -0.2236407], [5.6136752, -0.2238238], [5.613226, -0.2254029], [5.6129305, -0.2263379], [5.6126113, -0.2273714], [5.6125616, -0.2275149], [5.6123701, -0.228189], [5.6122231, -0.228673], [5.6120644, -0.2291719], [5.61185, -0.229847], [5.6116011, -0.230693], [5.6116148, -0.2309543], [5.6116055, -0.23101], [5.61144, -0.2315962], [5.6112548, -0.2322149], [5.6110908, -0.2328], [5.6108713, -0.2335452], [5.6105842, -0.2344823], [5.610447, -0.2348628], [5.6104143, -0.2349535], [5.610236, -0.2355669], [5.6101492, -0.235843], [5.6098678, -0.2367547], [5.6

# %% [markdown]
# ### Export as GIS

# %%
feed.write_geojson(
    'outputs/accra/' # folder name in which will be written 3 geojson files: routes, stops and trips
)
# Out:
# routes - stops - trips:   0%|          | 0/3 [00:00<?, ?it/s]
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
# ...
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# routes - stops - trips: 100%|██████████| 3/3 [00:04<00:00,  1.50s/it]

# %% [markdown]
# ### Create shapes for trips from stops, if they are missing

# %%
feed = Feed(path=data + r'paris_ratp_full', dist_units='m')
feed = feed.clean()
feed.describe()
# Out:
#           indicator                                              value
# 0          agencies                                       [RATP (100)]
# 1  running_services  [12639389, 12676692, 12672434, 2679680, 126617...
# 2          timezone                                                CET
# 3        start_date                                           20181003
# 4          end_date                                           20190101
# 5        num_routes                                                989
# 6         num_trips                                                989
# 7         num_stops                                              22352
# 8        num_shapes                                                  0
# 9   num_frequencies                                                  0

# %%
feed.shapes # returns nothing

# %%
feed = feed.create_shapes() # create_shapes returns a new feed

# %%
feed.shapes.head()  # Now we have some shapes
# Out:
#     shape_id  shape_pt_sequence  shape_pt_lon  shape_pt_lat
# 0  shape_000                  0      2.367038     48.826948
# 1  shape_000                  1      2.376120     48.829831
# 2  shape_000                  2      2.386265     48.833521
# 3  shape_000                  3      2.379409     48.840543
# 4  shape_000                  4      2.373108     48.844652

# %%
feed.map_trips(
    feed.trips.groupby('route_id').first().trip_id.head(50)
)
# Out:
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_181aa50735e332d73b84513af243b8f7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_181aa50735e332d73b84513af243b8f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_181aa50735e332d73b84513af243b8f7 = L.map(
#                 &quot;map_181aa50735e332d73b84513af243b8f7&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_147da1ae2a26fa5a30ec9dc861b4b610 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_181aa50735e332d73b84513af243b8f7);
#
#
#             var feature_group_f52551ca63139a81b9cc7b6eb7cb2005 = L.featureGroup(
#                 {}
#             ).addTo(map_181aa50735e332d73b84513af243b8f7);
#
#
#             var poly_line_7f30503f2858f57d61526aea9d5cdd8c = L.polyline(
#                 [[48.69168964503534, 2.334186286277667], [48.68961319475132, 2.331864845590076], [48.6867817158122, 2.330616178567413], [48.68504702317777, 2.333141387022622], [48.68339318243568, 2.3376211914319307], [48.68106502916987, 2.3418834617169133], [48.67873671160133, 2.346240365571396], [48.6770825231923, 2.349280459544054], [48.68018291128831, 2.354941505807853], [48.68284267569443, 2.3601007677690373], [48.68816445328174, 2.3573200215398398], [48.689378366309775, 2.3544558838862235], [48.69097881776177, 2.350749960762494], [48.6932893287219, 2.346039219363003], [48.69713611014286, 2.3497060248892825], [48.70137835800327, 2.352653783738852], [48.70517122890431, 2.3547055550080347], [48.709511885928855, 2.359406240118037], [48.71290818217382, 2.365709954080588], [48.71292568475095, 2.367625092989593], [48.71434466023632, 2.371999598783743]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#66c2a5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#66c2a5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_f52551ca63139a81b9cc7b6eb7cb2005);
#
#
#         var popup_40ae94bc796224d383faae5b8674941f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_057abde967266776e72898c3345a48d3 = $(`&lt;div id=&quot;html_057abde967266776e72898c3345a48d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;table class=&#x27;table table-condensed table-hover&#x27;&gt;&lt;tr&gt;&lt;th&gt;shape_id&lt;/th&gt;&lt;td&gt;shape_537&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th&gt;route_id&lt;/th&gt;&lt;td&gt;1025209&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th&gt;service_id&lt;/th&gt;&lt;td&gt;2689845&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th&gt;trip_id&lt;/th&gt;&lt;td&gt;126898451022105&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th&gt;trip_headsign&lt;/th&gt;&lt;td&gt;None&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th&gt;trip_short_name&lt;/th&gt;&lt;td&gt;1&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th&gt;direction_id&lt;/th&gt;&lt;td&gt;1&lt;/td&gt;&lt;/tr&gt;&lt;/table&gt;&lt;/div&gt;`)[0];
#             popup_40ae94bc796224d383faae5b8674941f.setContent(html_057abde967266776e72898c3345a48d3);
#
#
#         poly_line_7f30503f2858f57d61526aea9d5cdd8c.bindPopup(popup_40ae94bc796224d383faae5b8674941f)
#         ;
#
#
#
#
#             var feature_group_3c9c899fad6af452a3873f9b6aea4d8d = L.featureGroup(
#                 {}
#             ).addTo(map_181aa50735e332d73b84513af243b8f7);
#
#
#             var poly_line_d7598ff8773ad397ab8bc57cf81a020b = L.polyline(
#                 [[48.68519980683365, 2.332516913899929], [48.69289383685861, 2.3459576890824585], [48.69036746920007, 2.3517951995057187], [48.68893782592309, 2.3551209728143228], [48.68805660585001, 2.3572249480463734], [48.69713611014286, 2.3497060248892825], [48.70137835800327, 2.352653783738852], [48.70517122890431, 2.3547055550080347], [48.709511885928855, 2.359406240118037], [48.71290818217382, 2.365709954080588], [48.71292568475095, 2.367625092989593], [48.71434466023632, 2.371999598783743]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fc8d62&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#fc8d62&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quo
