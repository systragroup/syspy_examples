# %%
qpath = r'../../quetzal/' # path to quetzal here
import sys
sys.path.insert(0, qpath)

data = r'inputs/'

# import class
from quetzal.io.gtfs_reader import importer
# Out:
# C:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_env\lib\site-packages\tqdm\std.py:697: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
import numpy as np

# %% [markdown]
# ### Read GTFS

# %%
feed = importer.GtfsImporter(path=data + r'bilbao.zip', dist_units='m')
feed = feed.clean()
feed.describe()
# Out:
#           indicator          value
# 0          agencies     [Bilbobus]
# 1  running_services            [1]
# 2          timezone  Europe/Madrid
# 3        start_date       20191210
# 4          end_date       20200310
# 5        num_routes             82
# 6         num_trips           3297
# 7         num_stops            498
# 8        num_shapes              0
# 9   num_frequencies              0

# %%
feed.validate()
# Out:
#       type                                  message       table  \
# 0  warning                             Feed expired    calendar
# 1  warning  Repeated pair (trip_id, departure_time)  stop_times
#
#                                                 rows
# 0                                                 []
# 1  [128, 4087, 4101, 4115, 4129, 4143, 4157, 4171...

# %%
feed.map_stops(feed.stops.stop_id)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
feed = feed.create_shapes()

# %%
feed.map_trips(
    feed.trips.groupby('route_id').first().trip_id.head(50)
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Frequency conversion currently work only for one specific service and date, and on one given time period.
# It computes the average headway over this time period.

# %% [markdown]
# ### Restrict to one date and merge services

# %%
feed = feed.restrict(dates=['20191210'])
feed.group_services()

# %%
feed.describe()
# Out:
#           indicator          value
# 0          agencies     [Bilbobus]
# 1  running_services            [1]
# 2          timezone  Europe/Madrid
# 3        start_date       20191210
# 4          end_date       20191210
# 5        num_routes             82
# 6         num_trips           3297
# 7         num_stops            498
# 8        num_shapes            124
# 9   num_frequencies              0

# %% [markdown]
# ### Build simplified patterns by clustering stops

# %%
feed.build_stop_clusters(distance_threshold=300)

# %%
print('N stops:', len(feed.stops))
print('N clusters:', len(feed.stops.cluster_id.unique()))
# Out:
# N stops: 498
# N clusters: 165

# %%
feed.build_patterns(on='cluster_id')

# %%
print('N trips:', len(feed.trips))
print('N patterns:', len(feed.trips.pattern_id.unique()))
print('N routes:', len(feed.trips.route_id.unique()))
# Out:
# N trips: 3297
# N patterns: 124
# N routes: 82

# %%
feed.describe()
# Out:
#           indicator          value
# 0          agencies     [Bilbobus]
# 1  running_services            [1]
# 2          timezone  Europe/Madrid
# 3        start_date       20191210
# 4          end_date       20191210
# 5        num_routes             82
# 6         num_trips           3297
# 7         num_stops            498
# 8        num_shapes            124
# 9   num_frequencies              0

# %% [markdown]
# ### Convert to frequencies

# %%
feed.stop_times
# Out:
#       trip_id arrival_time departure_time stop_id  stop_sequence  \
# 0      406305     06:15:00       06:15:00    5405              1
# 1      406305     06:17:00       06:17:00    5106              2
# 2      406305     06:21:00       06:21:00    5110              3
# 3      406305     06:23:00       06:23:00    2108              4
# 4      406305     06:24:00       06:24:00    2104              5
# ...       ...          ...            ...     ...            ...
# 57134  436376     14:03:00       14:03:00    5101              8
# 57135  436376     14:08:00       14:08:00    5704              9
# 57136  436376     14:11:00       14:11:00    5601             10
# 57137  436376     14:13:00       14:13:00    5701             11
# 57138  436376     14:15:00       14:15:00    5405             12
#
#       stop_headsign  pickup_type  drop_off_type  shape_dist_traveled
# 0               NaN            0              0                  NaN
# 1               NaN            0              0                  NaN
# 2               NaN            0              0                  NaN
# 3               NaN            0              0                  NaN
# 4               NaN            0              0                  NaN
# ...             ...          ...            ...                  ...
# 57134           NaN            0              0                  NaN
# 57135           NaN            0              0                  NaN
# 57136           NaN            0              0                  NaN
# 57137           NaN            0              0                  NaN
# 57138           NaN            0              0                  NaN
#
# [57139 rows x 9 columns]

# %%
time_range = ['08:00:00', '10:00:00']  # time format must be HH:MM:SS
feed_f = feed.convert_to_frequencies(time_range=time_range)
# Out:
# 100%|██████████| 75/75 [00:00<00:00, 138.48it/s]

# %%
feed_f = feed.convert_to_frequencies(time_range=time_range)
# Out:
# 100%|██████████| 75/75 [00:00<00:00, 141.64it/s]

# %%
feed_f.describe()
# Out:
#           indicator          value
# 0          agencies     [Bilbobus]
# 1  running_services            [1]
# 2          timezone  Europe/Madrid
# 3        start_date       20191210
# 4          end_date       20191210
# 5        num_routes             67
# 6         num_trips             75
# 7         num_stops            495
# 8        num_shapes             75
# 9   num_frequencies             75

# %% [markdown]
# ### Build nodes and links

# %%
feed_f.build_links_and_nodes()
# Out:
# export geometries in epsg: 32630

# %%
feed_f.nodes.head(1).T
# Out:
#                                                          0
# stop_id                                               2201
# stop_code                                              NaN
# stop_name                            Anselma de Salces (2)
# stop_desc                                              NaN
# zone_id                                                NaN
# stop_url                                               NaN
# location_type                                          NaN
# cluster_id                                              85
# geometry       POINT (506258.4033893289 4790384.018252368)

# %%
feed_f.links.head(1).T
# Out:
#                                                                   0
# index                                                             0
# a                                                              5405
# trip_id                                                       201_0
# link_sequence                                                     1
# departure_time                                                29700
# pickup_type                                                       0
# b                                                              5106
# arrival_time                                                  29820
# drop_off_type                                                     0
# time                                                            120
# headway                                                        1800
# pattern_id                                                    201_0
# route_id                                                        201
# service_id                                                        1
# trip_headsign                                                Atxuri
# direction_id                                                    NaN
# shape_id                                                  shape_036
# agency_id                                                        27
# route_short_name                                             22_VLT
# route_long_name                                   Sarrikue - Atxuri
# route_desc                                                      NaN
# route_type                                                        3
# route_url                                                       NaN
# route_color                                                     NaN
# geometry          LINESTRING (506286.0234847061 4789138.90647092...

# %% [markdown]
# ## All in one
# While we recommand to build the nodes and links gradually by exploring the GTFS data first, it is also possible to do it in one line.

# %%
feed = importer.GtfsImporter(path=data + r'bilbao.zip', dist_units='m')
feed.describe()
# Out:
#           indicator          value
# 0          agencies     [Bilbobus]
# 1  running_services            [1]
# 2          timezone  Europe/Madrid
# 3        start_date       20191210
# 4          end_date       20200310
# 5        num_routes             92
# 6         num_trips           3297
# 7         num_stops            498
# 8        num_shapes              0
# 9   num_frequencies              0

# %%
imp = feed.build(
    date='20191210',
    time_range=['08:00:00', '10:00:00'],
    cluster_distance_threshold=300 # by default: None and no clustering
)
# Out:
# Restricting to date…
# Grouping services…
# Clustering stops…
# Building patterns…
#  16%|█▌        | 11/69 [00:00<00:00, 107.84it/s]
# Converting to frequencies…
# 100%|██████████| 69/69 [00:00<00:00, 124.16it/s]
# Building links and nodes…
# export geometries in epsg: 32630

# %%
imp.describe()
# Out:
#           indicator          value
# 0          agencies     [Bilbobus]
# 1  running_services            [1]
# 2          timezone  Europe/Madrid
# 3        start_date       20191210
# 4          end_date       20191210
# 5        num_routes             67
# 6         num_trips             69
# 7         num_stops            495
# 8        num_shapes              0
# 9   num_frequencies             69

# %%
imp.links.head()
# Out:
#    index     a trip_id  link_sequence  departure_time  pickup_type     b  \
# 0      0  5405   201_0              1         29700.0            0  5106
# 1      1  5106   201_0              2         29820.0            0  5110
# 2      2  5110   201_0              3         30060.0            0  2108
# 3      3  2108   201_0              4         30180.0            0  2104
# 4      4  2104   201_0              5         30240.0            0  2206
#
#    arrival_time  drop_off_type   time  ...  direction_id shape_id agency_id  \
# 0       29820.0              0  120.0  ...           NaN      NaN        27
# 1       30060.0              0  240.0  ...           NaN      NaN        27
# 2       30180.0              0  120.0  ...           NaN      NaN        27
# 3       30240.0              0   60.0  ...           NaN      NaN        27
# 4       30360.0              0  120.0  ...           NaN      NaN        27
#
#   route_short_name    route_long_name  route_desc  route_type route_url  \
# 0           22_VLT  Sarrikue - Atxuri         NaN           3       NaN
# 1           22_VLT  Sarrikue - Atxuri         NaN           3       NaN
# 2           22_VLT  Sarrikue - Atxuri         NaN           3       NaN
# 3           22_VLT  Sarrikue - Atxuri         NaN           3       NaN
# 4           22_VLT  Sarrikue - Atxuri         NaN           3       NaN
#
#   route_color                                           geometry
# 0         NaN  LINESTRING (506286.023 4789138.906, 506030.167...
# 1         NaN  LINESTRING (506030.167 4789312.701, 506269.426...
# 2         NaN  LINESTRING (506269.426 4789737.628, 506202.215...
# 3         NaN  LINESTRING (506202.215 4790128.260, 506068.589...
# 4         NaN  LINESTRING (506068.589 4790271.632, 506071.610...
#
# [5 rows x 25 columns]

# %%
imp.nodes.head()
# Out:
#   stop_id stop_code                      stop_name stop_desc zone_id stop_url  \
# 0    2201       NaN          Anselma de Salces (2)       NaN     NaN      NaN
# 1    2417       NaN                    Trauko (14)       NaN     NaN      NaN
# 2    3103       NaN  Kepa Enbeitia "Urretxindorra"       NaN     NaN      NaN
# 3    6209       NaN          Gregorio la Revilla 1       NaN     NaN      NaN
# 4    6210       NaN         Gregorio la Revilla 17       NaN     NaN      NaN
#
#    location_type  cluster_id                        geometry
# 0            NaN          85  POINT (506258.403 4790384.018)
# 1            NaN          10  POINT (506528.037 4790435.054)
# 2            NaN         157  POINT (508092.006 4789626.524)
# 3            NaN          56  POINT (504935.494 4790091.282)
# 4            NaN          79  POINT (504867.070 4789866.493)
