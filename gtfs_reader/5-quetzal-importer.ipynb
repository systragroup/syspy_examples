# %%
qpath = r'../../quetzal/' # path to quetzal here
import sys
sys.path.insert(0, qpath)

data = r'inputs/'

# import class
from quetzal.io.gtfs_reader import importer

# %%
import numpy as np

# %% [markdown]
# ### Read GTFS

# %%
feed = importer.GtfsImporter(path=data + r'bilbao.zip', dist_units='m')
feed = feed.clean()
feed.describe()
# Out:
#           indicator          value
# 0          agencies     [Bilbobus]
# 1  running_services            [1]
# 2          timezone  Europe/Madrid
# 3        start_date       20191210
# 4          end_date       20200310
# 5        num_routes             82
# 6         num_trips           3297
# 7         num_stops            498
# 8        num_shapes              0
# 9   num_frequencies              0

# %%
feed.validate()
# Out:
#       type                                  message       table  \
# 0  warning                             Feed expired    calendar
# 1  warning  Repeated pair (trip_id, departure_time)  stop_times
#
#                                                 rows
# 0                                                 []
# 1  [128, 4087, 4101, 4115, 4129, 4143, 4157, 4171...

# %%
feed.map_stops(feed.stops.stop_id)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_165573cae0836a184f04a987ccddece8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_165573cae0836a184f04a987ccddece8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_165573cae0836a184f04a987ccddece8 = L.map(
#                 &quot;map_165573cae0836a184f04a987ccddece8&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f6b1007d7c9f096033cc7afe468b6d1 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_165573cae0836a184f04a987ccddece8);
#
#
#             var fast_marker_cluster_286888816fa3295186eca45cc0681409 = (function(){
#                 var callback =     function (row) {
#         var imarker;
#         marker = L.circleMarker(new L.LatLng(row[0], row[1]),
#             {&#x27;radius&#x27;: 8, &#x27;fill&#x27;: &#x27;true&#x27;, &#x27;color&#x27;: &#x27;#fc8d62&#x27;, &#x27;weight&#x27;: 1, &#x27;fillOpacity&#x27;: 0.75}
#         );
#         marker.bindPopup(
#             &#x27;&lt;b&gt;Stop name&lt;/b&gt;: &#x27; + row[2] + &#x27;&lt;br&gt;&#x27; +
#             &#x27;&lt;b&gt;Stop ID&lt;/b&gt;: &#x27; + row[3]
#         );
#         return marker;
#     };
#     ;
#
#                 var data = [[43.26624131429908, -2.9228838481644965, &quot;Anselma de Salces (2)&quot;, &quot;2201&quot;], [43.26669858239837, -2.919560820286531, &quot;Trauko (14)&quot;, &quot;2417&quot;], [43.25940287658717, -2.9003013269964155, &quot;Kepa Enbeitia \&quot;Urretxindorra\&quot;&quot;, &quot;3103&quot;], [43.26361514635327, -2.939187371896199, &quot;Gregorio la Revilla 1&quot;, &quot;6209&quot;], [43.26159143904042, -2.940032450190756, &quot;Gregorio la Revilla 17&quot;, &quot;6210&quot;], [43.24892278433412, -2.9447945395166992, &quot;Xalbador / (Alh\u00f3ndiga)&quot;, &quot;7317&quot;], [43.24887527450186, -2.9447514983842766, &quot;Xalbador / Alh\u00f3ndiga&quot;, &quot;7318&quot;], [43.25017292995476, -2.9447701476848467, &quot;Xalbador / F.Baldezate&quot;, &quot;7319&quot;], [43.246988383125895, -2.9506023242918595, &quot;Armotxabidea&quot;, &quot;7511&quot;], [43.25622794394357, -2.946453878080568, &quot;Urkiola 1&quot;, &quot;8118&quot;], [43.26252793147444, -2.947342656750676, &quot;Urquijo 100&quot;, &quot;8124&quot;], [43.27770922600834, -2.960792645901257, &quot;L. Aguirre 149&quot;, &quot;1101&quot;], [43.27883335209484, -2.961194408039843, &quot;L. Aguirre 154&quot;, &quot;1102&quot;], [43
],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#66c2a5&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#66c2a5&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_b1866dd9e259de11fba83952e5c00cdc);
#
#
#         var popup_325e82fe45310b152f31f06597c21140 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f338bd5b23ce19d11e2daeb109dc3022 = $(`&lt;div id=&quot;html_f338bd5b23ce19d11e2daeb109dc3022&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;table class=&#x27;table table-condensed table-hover&#x27;&gt;&lt;tr&gt;&lt;th&gt;shape_id&lt;/th&gt;&lt;td&gt;shape_009&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th&gt;route_id&lt;/th&gt;&lt;td&gt;189&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th&gt;service_id&lt;/th&gt;&lt;td&gt;1&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th&gt;trip_id&lt;/th&gt;&lt;td&gt;414668&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th&gt;trip_headsign&lt;/th&gt;&lt;td&gt; Plaza Biribila&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th&gt;direction_id&lt;/th&gt;&lt;td&gt;None&lt;/td&gt;&lt;/tr&gt;&lt;/table&gt;&lt;/div&gt;`)[0];
#             popup_325e82fe45310b152f31f06597c21140.setContent(html_f338bd5b23ce19d11e2daeb109dc3022);
#
#
#         poly_line_cbf0637d5dfbeeff0d13902092900e78.bindPopup(popup_325e82fe45310b152f31f06597c21140)
#         ;
#
#
#
#
#             var feature_group_3bf5cfbd31136a6715dafe0f04061acd = L.featureGroup(
#                 {}
#             ).addTo(map_59f81c6615d7bb4bfe9d09a626751c9b);
#
#
#             var poly_line_47f2c39c01ab383c89d734408a862281 = L.polyline(
#                 [[43.26147889006099, -2.927827856851289], [43.26270986739097, -2.9334572387021574], [43.263930990878336, -2.935556936555513], [43.26586473617383, -2.936982208468321], [43.267576321568185, -2.939370056620456], [43.271026024215, -2.941239878666445], [43.271947806075474, -2.9450853957722547], [43.272121575479495, -2.9505942087362915], [43.27365224000173, -2.9544278519277545], [43.27538311626563, -2.953643318009604], [43.27544806274924, -2.9523955725224766], [43.274140420793564, -2.94974139187303], [43.27409898511566, -2.9484594192014417], [43.274474567193614, -2.9471995607698838], [43.27541244308709, -2.9474208576466827]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fc8d62&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#fc8d62&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_3bf5cfbd31136a6715dafe0f04061acd);
#
#
#         var popup_13ceca195dab244f15786d2f0cec5b2e = L.popup({&quot;maxWi

# %% [markdown]
# Frequency conversion currently work only for one specific service and date, and on one given time period.
# It computes the average headway over this time period.

# %% [markdown]
# ### Restrict to one date and merge services

# %%
feed = feed.restrict(dates=['20191210'])
feed.group_services()
# Out:
# c:\Users\rgoix\Documents\dev\formation\syspy_examples\gtfs_reader\../../quetzal\quetzal\io\gtfs_reader\filtering.py:264: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_calendar_dates = new_calendar_dates.append(

# %%
feed.describe()
# Out:
#           indicator          value
# 0          agencies     [Bilbobus]
# 1  running_services            [1]
# 2          timezone  Europe/Madrid
# 3        start_date       20191210
# 4          end_date       20191210
# 5        num_routes             82
# 6         num_trips           3297
# 7         num_stops            498
# 8        num_shapes            124
# 9   num_frequencies              0

# %% [markdown]
# ### Build simplified patterns by clustering stops

# %%
feed.build_stop_clusters(distance_threshold=300)

# %%
print('N stops:', len(feed.stops))
print('N clusters:', len(feed.stops.cluster_id.unique()))
# Out:
# N stops: 498
# N clusters: 165

# %%
feed.build_patterns(on='cluster_id')

# %%
print('N trips:', len(feed.trips))
print('N patterns:', len(feed.trips.pattern_id.unique()))
print('N routes:', len(feed.trips.route_id.unique()))
# Out:
# N trips: 3297
# N patterns: 124
# N routes: 82

# %%
feed.describe()
# Out:
#           indicator          value
# 0          agencies     [Bilbobus]
# 1  running_services            [1]
# 2          timezone  Europe/Madrid
# 3        start_date       20191210
# 4          end_date       20191210
# 5        num_routes             82
# 6         num_trips           3297
# 7         num_stops            498
# 8        num_shapes            124
# 9   num_frequencies              0

# %% [markdown]
# ### Convert to frequencies

# %%
feed.stop_times
# Out:
#       trip_id arrival_time departure_time stop_id  stop_sequence  \
# 0      406305     06:15:00       06:15:00    5405              1
# 1      406305     06:17:00       06:17:00    5106              2
# 2      406305     06:21:00       06:21:00    5110              3
# 3      406305     06:23:00       06:23:00    2108              4
# 4      406305     06:24:00       06:24:00    2104              5
# ...       ...          ...            ...     ...            ...
# 57134  436376     14:03:00       14:03:00    5101              8
# 57135  436376     14:08:00       14:08:00    5704              9
# 57136  436376     14:11:00       14:11:00    5601             10
# 57137  436376     14:13:00       14:13:00    5701             11
# 57138  436376     14:15:00       14:15:00    5405             12
#
#       stop_headsign  pickup_type  drop_off_type  shape_dist_traveled
# 0               NaN            0              0                  NaN
# 1               NaN            0              0                  NaN
# 2               NaN            0              0                  NaN
# 3               NaN            0              0                  NaN
# 4               NaN            0              0                  NaN
# ...             ...          ...            ...                  ...
# 57134           NaN            0              0                  NaN
# 57135           NaN            0              0                  NaN
# 57136           NaN            0              0                  NaN
# 57137           NaN            0              0                  NaN
# 57138           NaN            0              0                  NaN
#
# [57139 rows x 9 columns]

# %%
time_range = ['08:00:00', '10:00:00']  # time format must be HH:MM:SS
feed_f = feed.convert_to_frequencies(time_range=time_range)
# Out:
# c:\Users\rgoix\Documents\dev\formation\syspy_examples\gtfs_reader\../../quetzal\quetzal\io\gtfs_reader\frequencies.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_frequencies = temp_frequencies.append(temp_stop_times)

# %%
feed_f = feed.convert_to_frequencies(time_range=time_range)
# Out:
# c:\Users\rgoix\Documents\dev\formation\syspy_examples\gtfs_reader\../../quetzal\quetzal\io\gtfs_reader\frequencies.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_frequencies = temp_frequencies.append(temp_stop_times)

# %%
feed_f.describe()
# Out:
#           indicator          value
# 0          agencies     [Bilbobus]
# 1  running_services            [1]
# 2          timezone  Europe/Madrid
# 3        start_date       20191210
# 4          end_date       20191210
# 5        num_routes             67
# 6         num_trips             75
# 7         num_stops            495
# 8        num_shapes             75
# 9   num_frequencies             75

# %% [markdown]
# ### Build nodes and links

# %%
feed_f.build_links_and_nodes()
# Out:
# export geometries in epsg: 32630
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)

# %%
feed_f.nodes.head(1).T
# Out:
#                                                           0
# stop_id                                                2201
# stop_code                                               NaN
# stop_name                             Anselma de Salces (2)
# stop_desc                                               NaN
# zone_id                                                 NaN
# stop_url                                                NaN
# location_type                                           NaN
# cluster_id                                               85
# geometry       POINT (506258.40338932886 4790384.018252368)

# %%
feed_f.links.head(1).T
# Out:
#                                                                   0
# index                                                             0
# a                                                              1604
# trip_id                                                       189_0
# link_sequence                                                     1
# departure_time                                              27900.0
# b                                                              1605
# arrival_time                                                27960.0
# time                                                           60.0
# headway                                                         900
# pattern_id                                                    189_0
# route_id                                                        189
# service_id                                                        1
# trip_headsign                                        Plaza Biribila
# direction_id                                                    NaN
# shape_id                                                  shape_009
# agency_id                                                        27
# route_short_name                                             01_IDA
# route_long_name                          Arangoiti - Plaza Biribila
# route_desc                                                      NaN
# route_type                                                        3
# route_url                                                       NaN
# route_color                                                     NaN
# geometry          LINESTRING (504266.4483006593 4791400.96020436...

# %% [markdown]
# ## All in one
# While we recommand to build the nodes and links gradually by exploring the GTFS data first, it is also possible to do it in one line.

# %%
feed = importer.GtfsImporter(path=data + r'bilbao.zip', dist_units='m')
feed.describe()
# Out:
#           indicator          value
# 0          agencies     [Bilbobus]
# 1  running_services            [1]
# 2          timezone  Europe/Madrid
# 3        start_date       20191210
# 4          end_date       20200310
# 5        num_routes             92
# 6         num_trips           3297
# 7         num_stops            498
# 8        num_shapes              0
# 9   num_frequencies              0

# %%
imp = feed.build(
    date='20191210',
    time_range=['08:00:00', '10:00:00'],
    cluster_distance_threshold=300 # by default: None and no clustering
)
# Out:
# Restricting to date…
# Grouping services…
# Clustering stops…
# Building patterns…
# c:\Users\rgoix\Documents\dev\formation\syspy_examples\gtfs_reader\../../quetzal\quetzal\io\gtfs_reader\filtering.py:264: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_calendar_dates = new_calendar_dates.append(
# Converting to frequencies…
# c:\Users\rgoix\Documents\dev\formation\syspy_examples\gtfs_reader\../../quetzal\quetzal\io\gtfs_reader\frequencies.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_frequencies = temp_frequencies.append(temp_stop_times)
# Building links and nodes…
# export geometries in epsg: 32630
# c:\Users\rgoix\AppData\Local\Continuum\anaconda3\envs\quetzal_latest\lib\site-packages\pandas\core\dtypes\cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)

# %%
imp.describe()
# Out:
#           indicator          value
# 0          agencies     [Bilbobus]
# 1  running_services            [1]
# 2          timezone  Europe/Madrid
# 3        start_date       20191210
# 4          end_date       20191210
# 5        num_routes             67
# 6         num_trips             69
# 7         num_stops            495
# 8        num_shapes              0
# 9   num_frequencies             69

# %%
imp.links.head()
# Out:
#    index     a trip_id  link_sequence  departure_time     b  arrival_time  \
# 0      0  1604   189_0              1         27900.0  1605       27960.0
# 1      1  1605   189_0              2         27960.0  1702       28140.0
# 2      2  1702   189_0              3         28140.0  1703       28200.0
# 3      3  1703   189_0              4         28200.0  1306       28440.0
# 4      4  1306   189_0              5         28440.0  1414       28680.0
#
#     time  headway pattern_id  ... direction_id shape_id agency_id  \
# 0   60.0      900      189_0  ...          NaN     None        27
# 1  180.0      900      189_0  ...          NaN     None        27
# 2   60.0      900      189_0  ...          NaN     None        27
# 3  240.0      900      189_0  ...          NaN     None        27
# 4  240.0      900      189_0  ...          NaN     None        27
#
#    route_short_name             route_long_name route_desc route_type  \
# 0            01_IDA  Arangoiti - Plaza Biribila        NaN          3
# 1            01_IDA  Arangoiti - Plaza Biribila        NaN          3
# 2            01_IDA  Arangoiti - Plaza Biribila        NaN          3
# 3            01_IDA  Arangoiti - Plaza Biribila        NaN          3
# 4            01_IDA  Arangoiti - Plaza Biribila        NaN          3
#
#   route_url route_color                                           geometry
# 0       NaN         NaN  LINESTRING (504266.448 4791400.960, 504088.197...
# 1       NaN         NaN  LINESTRING (504088.197 4791399.303, 503796.023...
# 2       NaN         NaN  LINESTRING (503796.023 4791563.341, 503745.174...
# 3       NaN         NaN  LINESTRING (503745.174 4791526.405, 503618.056...
# 4       NaN         NaN  LINESTRING (503618.056 4791226.062, 504049.581...
#
# [5 rows x 23 columns]

# %%
imp.nodes.head()
# Out:
#   stop_id stop_code                      stop_name stop_desc zone_id stop_url  \
# 0    2201       NaN          Anselma de Salces (2)       NaN     NaN      NaN
# 1    2417       NaN                    Trauko (14)       NaN     NaN      NaN
# 2    3103       NaN  Kepa Enbeitia "Urretxindorra"       NaN     NaN      NaN
# 3    6209       NaN          Gregorio la Revilla 1       NaN     NaN      NaN
# 4    6210       NaN         Gregorio la Revilla 17       NaN     NaN      NaN
#
#    location_type  cluster_id                        geometry
# 0            NaN          85  POINT (506258.403 4790384.018)
# 1            NaN          10  POINT (506528.037 4790435.054)
# 2            NaN         157  POINT (508092.006 4789626.524)
# 3            NaN          56  POINT (504935.494 4790091.282)
# 4            NaN          79  POINT (504867.070 4789866.493)
